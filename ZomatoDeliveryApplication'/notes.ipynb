# %% [markdown]
# # Design a Food Delivery App -> Tomato
#
# ## Functional Requirements
# - user can serarch for restaurants based on location
# - user can add iterms to cart
# - user can checkout by making payments
# - user should be notified once the order is placed successfully
#
#
# ## Non-functional requirements
# - each and desing shoul dbe scalable and modifiable

# %% [markdown]
# ### Happy Flow
# <img src = 'Screenshot 2026-04-10 195208.png'>

# %% [markdown]
# ### UML Diagram
# <img src = 'Screenshot 2026-04-10 215354.png'>
